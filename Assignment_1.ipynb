# %% [markdown]
# 1.	Write a Python program to print "Hello Python"

# %%
def print1():
    """Prints Hello Python string"""
    print("Hello Python")

# %%
print1()
# Out:
# Hello Python

# %% [markdown]
# 2.	Write a Python program to do arithmetical operations addition and division

# %%
try:
    a= int(input())
    b=int(input())
    c=a+b
    d=a/b
    print("Addition:", c)
    print("Divsion:", d)
except Exception as e: 
    print("Error:",e)
# Out:
# 12
# 6
# Addition: 18
# Divsion: 2.0

# %% [markdown]
# 3.	Write a Python program to find the area of a triangle

# %%
def triangle():
    """Returns area of the traingle"""
    base= int(input())
    height= int(input())
    area=(height*base/2)
    return area

# %%
triangle()
# Out:
# 23
# 76
# 874.0

# %% [markdown]
# 4.	Write a Python program to swap two variables

# %%
def swap():
    """Swaps the values of two variables"""
    v1=int(input())
    v2=int(input())
    print("Before swapping:", v1,v2)
    temp=v1
    v1=v2
    v2=temp
    print("After swapping:", v1,v2)

# %%
swap()
# Out:
# 43
# 65
# Before swapping: 43 65
# After swapping: 65 43

# %% [markdown]
# 5.	Write a Python program to generate a random number

# %%
def randomvar():
    """Generates and return a random number"""
    import random
    var= random.random()
    return var

# %%
randomvar()
# Out:
# 0.8814997002962676
